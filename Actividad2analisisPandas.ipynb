# %% [markdown]
# <a href="https://colab.research.google.com/github/frontendbby/frontendbby/blob/main/Actividad2analisisPandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **MAESTRÍA EN INTELIGENCIA ARTIFICIAL APLICADA**
#
# **Curso: TC4029 - Ciencia y analítica de datos**
#
# Tecnológico de Monterrey
#
# Prof Grettel Barceló Alonso
#
# **Semana 2**
# Pandas para el análisis de datos en Python
#
# ---

# %% [markdown]
# *   NOMBRE: **Jessica Melani Romero Lora**
# ---------------------------------------------------------
# *   MATRÍCULA: **A01796083**

# %% [markdown]
# ---

# %% [markdown]
# En esta actividad usarás el archivo de datos `LaqnData.csv`. Cada fila de este conjunto de datos muestra un registro de medición, por hora, de uno de los siguientes cinco contaminantes del aire:
#
# *   `NO` (óxido nítrico)
# *   `NO2` (dióxido de nitrógeno)
# *   `NOX` (óxidos nitrosos)
# *   `PM10` (partículas suspendidas con un diámetro aerodinámico igual o menor a 10 micrómetros)
# *   `PM2.5` (partículas suspendidas con un diámetro aerodinámico igual o menor a 2.5 micrómetros)
#
# Los datos se recopilaron en una ubicación de Londres durante todo el año 2017.
#
# **NOTA IMPORTANTE:** Asegúrate de responder *explícitamente* todos los cuestionamientos.

# %% [markdown]
# 1.	Descarga el archivo: `LaqnData.csv` y guarda, en un dataframe (`air_df`), todos sus registros.
# *   Observa la estructura y contenido del dataframe con los atributos y métodos estudiados (`shape`, `columns`, `head()`, `tail()`, `dtypes`)
# *   Calcula el porcentaje de valores faltantes por columna.

# %%
# Importar los datos de mi carpeta personal MNA
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# Importar las librerias que ocuparemos para el proyecto de Data Science
import pandas as pd

# %%
# Lectura del archivo LaqnData.csv
pd.read_csv('/content/drive/MyDrive/MNA/LaqnData.csv')
# Out:
#       Site Species   ReadingDateTime  Value   Units Provisional or Ratified
# 0      CT3      NO  01/01/2017 00:00    3.5  ug m-3                       R
# 1      CT3      NO  01/01/2017 01:00    3.6  ug m-3                       R
# 2      CT3      NO  01/01/2017 02:00    2.2  ug m-3                       R
# 3      CT3      NO  01/01/2017 03:00    2.1  ug m-3                       R
# 4      CT3      NO  01/01/2017 04:00    3.3  ug m-3                       R
# ...    ...     ...               ...    ...     ...                     ...
# 43795  CT3   PM2.5  31/12/2017 19:00   -2.0  ug m-3                       R
# 43796  CT3   PM2.5  31/12/2017 20:00    6.0  ug m-3                       R
# 43797  CT3   PM2.5  31/12/2017 21:00    5.0  ug m-3                       R
# 43798  CT3   PM2.5  31/12/2017 22:00    5.0  ug m-3                       R
# 43799  CT3   PM2.5  31/12/2017 23:00    6.0  ug m-3                       R
#
# [43800 rows x 6 columns]

# %% [markdown]
# # **Demostracion de funcion Shape:**

# %%
df=pd.DataFrame()
air_df = '/content/drive/MyDrive/MNA/LaqnData.csv'
df = pd.read_csv(air_df)
df.shape
# Out:
# (43800, 6)

# %% [markdown]
# # **Demostracion de funcion Head:**

# %%
df=pd.DataFrame()
air_df = '/content/drive/MyDrive/MNA/LaqnData.csv'
df = pd.read_csv(air_df)
df.head(10)
# Out:
#   Site Species   ReadingDateTime  Value   Units Provisional or Ratified
# 0  CT3      NO  01/01/2017 00:00    3.5  ug m-3                       R
# 1  CT3      NO  01/01/2017 01:00    3.6  ug m-3                       R
# 2  CT3      NO  01/01/2017 02:00    2.2  ug m-3                       R
# 3  CT3      NO  01/01/2017 03:00    2.1  ug m-3                       R
# 4  CT3      NO  01/01/2017 04:00    3.3  ug m-3                       R
# 5  CT3      NO  01/01/2017 05:00    2.1  ug m-3                       R
# 6  CT3      NO  01/01/2017 06:00    4.4  ug m-3                       R
# 7  CT3      NO  01/01/2017 07:00    5.1  ug m-3                       R
# 8  CT3      NO  01/01/2017 08:00    7.4  ug m-3                       R
# 9  CT3      NO  01/01/2017 09:00    6.5  ug m-3                       R

# %% [markdown]
# # **Demostracion de funcion columns**

# %%
df=pd.DataFrame()
air_df = '/content/drive/MyDrive/MNA/LaqnData.csv'
df = pd.read_csv(air_df)
df.columns
# Out:
# Index(['Site', 'Species', 'ReadingDateTime', 'Value', 'Units',
#        'Provisional or Ratified'],
#       dtype='object')

# %% [markdown]
# # **Demostracion de funcion Tail**

# %%
df=pd.DataFrame()
air_df = '/content/drive/MyDrive/MNA/LaqnData.csv'
df = pd.read_csv(air_df)
df.tail()
# Out:
#       Site Species   ReadingDateTime  Value   Units Provisional or Ratified
# 43795  CT3   PM2.5  31/12/2017 19:00   -2.0  ug m-3                       R
# 43796  CT3   PM2.5  31/12/2017 20:00    6.0  ug m-3                       R
# 43797  CT3   PM2.5  31/12/2017 21:00    5.0  ug m-3                       R
# 43798  CT3   PM2.5  31/12/2017 22:00    5.0  ug m-3                       R
# 43799  CT3   PM2.5  31/12/2017 23:00    6.0  ug m-3                       R

# %% [markdown]
# # **Porcentaje de valores faltantes**

# %%
# Se calculo el porcentaje de valores faltantes unicamente para la columna 'Value'
# Unicamente los NaN'´s fueron tomados en cuenta

# %%
df=pd.DataFrame()
air_df = '/content/drive/MyDrive/MNA/LaqnData.csv'
df = pd.read_csv(air_df)
df['Value'].isna().mean()*100
# Out:
# 7.374429223744292

# %% [markdown]
# 2.	Obtén la cantidad de valores únicos por columna (`nunique()`) para responder:
#
#
# *   ¿Cuántas mediciones se hicieron?
# *   ¿Cuántos contaminantes del aire (`Species`) se analizaron?
# *   ¿Qué columnas no agregan ningún valor informativo porque el mismo valor en todo el conjunto de datos? Elimínalas del dataframe.
# *   La columna `Units` tampoco posee valor informativo. Verifícalo con la función `unique()` y elimínala del dataframe.

# %% [markdown]
# 3.	Realiza el conteo de valores por categoría (`value_counts()`) para la columna `Species` y determina si las lecturas de cada contaminante coincide con el total de mediciones.

# %%
# Primero llamare al Data Frame que estoy utilizando:

# %%
df=pd.DataFrame()
air_df = '/content/drive/MyDrive/MNA/LaqnData.csv'
df = pd.read_csv(air_df)
df.head(10)
# Out:
#   Site Species   ReadingDateTime  Value   Units Provisional or Ratified
# 0  CT3      NO  01/01/2017 00:00    3.5  ug m-3                       R
# 1  CT3      NO  01/01/2017 01:00    3.6  ug m-3                       R
# 2  CT3      NO  01/01/2017 02:00    2.2  ug m-3                       R
# 3  CT3      NO  01/01/2017 03:00    2.1  ug m-3                       R
# 4  CT3      NO  01/01/2017 04:00    3.3  ug m-3                       R
# 5  CT3      NO  01/01/2017 05:00    2.1  ug m-3                       R
# 6  CT3      NO  01/01/2017 06:00    4.4  ug m-3                       R
# 7  CT3      NO  01/01/2017 07:00    5.1  ug m-3                       R
# 8  CT3      NO  01/01/2017 08:00    7.4  ug m-3                       R
# 9  CT3      NO  01/01/2017 09:00    6.5  ug m-3                       R

# %%
# Numero de mediciones totales:
df.nunique()
# Out:
# Site                          1
# Species                       5
# ReadingDateTime            8760
# Value                      1847
# Units                         3
# Provisional or Ratified       1
# dtype: int64

# %%
# Columnas que no tienen valor porque se repiten en el Data Frame y seran eliminadas:
df.isna().sum()
# Out:
# Site                          0
# Species                       0
# ReadingDateTime               0
# Value                      3230
# Units                         0
# Provisional or Ratified       0
# dtype: int64

# %%
# Como podemos observar las columnas que mantienen el valor 0 son 3
# Esas son las que eliminaremos:

# %%
df.drop(columns=['Value',],inplace=True)

# %%
# Cuantos contaminantes del aire Species se analizaron?
df.Species.nunique()
# Out:
# 5

# %%
# Realizamos el conteo de valores por categoria unicamente para la columna Species:
df['Species'].value_counts()
# Out:
# Species
# NO       8760
# NO2      8760
# NOX      8760
# PM10     8760
# PM2.5    8760
# Name: count, dtype: int64

# %% [markdown]
# 4.	Utiliza la función `groupby()` para determinar el promedio del valor por contaminante.

# %% [markdown]
# 5.	El conjunto de datos está en un formato largo. Aplique la función apropiada para cambiarlo al formato ancho (`ReadingDateTime` como índice y cada contaminante en una columna). Nombre el dataframe resultante como `pvt_df`.

# %%
df=pd.DataFrame()
air_df = '/content/drive/MyDrive/MNA/LaqnData.csv'
df = pd.read_csv(air_df)
df.head(10)
# Out:
#   Site Species   ReadingDateTime  Value   Units Provisional or Ratified
# 0  CT3      NO  01/01/2017 00:00    3.5  ug m-3                       R
# 1  CT3      NO  01/01/2017 01:00    3.6  ug m-3                       R
# 2  CT3      NO  01/01/2017 02:00    2.2  ug m-3                       R
# 3  CT3      NO  01/01/2017 03:00    2.1  ug m-3                       R
# 4  CT3      NO  01/01/2017 04:00    3.3  ug m-3                       R
# 5  CT3      NO  01/01/2017 05:00    2.1  ug m-3                       R
# 6  CT3      NO  01/01/2017 06:00    4.4  ug m-3                       R
# 7  CT3      NO  01/01/2017 07:00    5.1  ug m-3                       R
# 8  CT3      NO  01/01/2017 08:00    7.4  ug m-3                       R
# 9  CT3      NO  01/01/2017 09:00    6.5  ug m-3                       R

# %%
#Funcion groupby() que determina el promedio del valor por contaminante
df.groupby('Species').mean(numeric_only=True)
# Out:
#              Value
# Species
# NO       15.045115
# NO2      38.010185
# NOX      61.078661
# PM10     22.551704
# PM2.5    14.999831

# %%
# Obtener el valor mayor de NO2 junto con el dia registrado
pvt_df = df.pivot(index='ReadingDateTime', columns='Species', values='Value')
pvt_df
# Out:
# Species            NO   NO2   NOX  PM10  PM2.5
# ReadingDateTime
# 01/01/2017 00:00  3.5  30.8  36.2  35.7    NaN
# 01/01/2017 01:00  3.6  31.5  37.0  28.5    NaN
# 01/01/2017 02:00  2.2  27.3  30.7  22.7    NaN
# 01/01/2017 03:00  2.1  23.5  26.8  20.5    NaN
# 01/01/2017 04:00  3.3  28.0  33.0  22.1    NaN
# ...               ...   ...   ...   ...    ...
# 31/12/2017 19:00  0.7  17.5  18.5  16.3   -2.0
# 31/12/2017 20:00  0.7  17.5  18.6  14.5    6.0
# 31/12/2017 21:00  0.7  14.1  15.1   8.6    5.0
# 31/12/2017 22:00  1.1  22.0  23.6  12.5    5.0
# 31/12/2017 23:00  0.9  19.4  20.7  10.4    6.0
#
# [8760 rows x 5 columns]

# %%
pvt_df.describe()
# Out:
# Species           NO          NO2          NOX         PM10        PM2.5
# count    8660.000000  8660.000000  8660.000000  8657.000000  5933.000000
# mean       15.045115    38.010185    61.078661    22.551704    14.999831
# std        26.678565    18.580841    54.584805    15.344755    13.558588
# min        -2.000000     2.800000     1.000000    -5.600000    -8.000000
# 25%         3.100000    23.800000    30.300000    13.900000     7.000000
# 50%         7.100000    35.300000    46.900000    19.500000    11.000000
# 75%        15.500000    49.900000    73.800000    27.300000    18.000000
# max       401.799990   120.200000   734.299990   633.099980   128.000000

# %% [markdown]
# 6.	A través de la función `describe()` responde:
#
# *   ¿Cuál es el mayor valor de `NO2` registrado? ¿A qué día pertenece?
# *   ¿Cuál es el menor valor de `PM10` registrado?¿A qué día pertenece?
# *   ¿Cuál es la mediana del `NO`? ¿Cómo se interpreta?
# *   ¿Cuál es el primer cuartil de `PM2.5`? ¿Qué significa?

# %%
# Respuesta 1. 120.2 es el mayor valor registrado de NO2 y pertenece al dia 24/01/2017

# Respuesta 2. -5.6 es el menor valor registrado de PM10 y pertenece a una fecha sin datos disponibles

# Respuesta 3. 4.6 es la media de NO y representa el valor de en medio de la distribucion normal de los datos

# Respuesta 4. 7.0 es el cuartil de PM2.5 y representa el 25% de los valores solamente

# %%
# Respuesta 3.
# Mediana de NO
df=pd.DataFrame()
air_df = '/content/drive/MyDrive/MNA/LaqnData.csv'
df = pd.read_csv(air_df)
df.head(10)
###############################################################################
pvt_df = df.pivot(index='ReadingDateTime', columns='Species', values='Value')
median = sorted(pvt_df['NO'])[len(pvt_df['NO']) // 2]
print(median)
# Out:
# 4.6

# %% [markdown]
# 7.	Dibuja un histograma para cada columna de `pvt_df`. ¿Qué contaminante tiene mayor variabilidad?

# %%
pvt_df['NO'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
pvt_df['NO2'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
pvt_df['NOX'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
pvt_df['PM10'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
pvt_df['PM2.5'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# 8.	Ejecuta el siguiente código y comenta qué hace cada línea:

# %%
pvt_df
# Out:
# Species            NO   NO2   NOX  PM10  PM2.5
# ReadingDateTime
# 01/01/2017 00:00  3.5  30.8  36.2  35.7    NaN
# 01/01/2017 01:00  3.6  31.5  37.0  28.5    NaN
# 01/01/2017 02:00  2.2  27.3  30.7  22.7    NaN
# 01/01/2017 03:00  2.1  23.5  26.8  20.5    NaN
# 01/01/2017 04:00  3.3  28.0  33.0  22.1    NaN
# ...               ...   ...   ...   ...    ...
# 31/12/2017 19:00  0.7  17.5  18.5  16.3   -2.0
# 31/12/2017 20:00  0.7  17.5  18.6  14.5    6.0
# 31/12/2017 21:00  0.7  14.1  15.1   8.6    5.0
# 31/12/2017 22:00  1.1  22.0  23.6  12.5    5.0
# 31/12/2017 23:00  0.9  19.4  20.7  10.4    6.0
#
# [8760 rows x 5 columns]

# %% [markdown]
# 9. Ejecuta la siguiente instrucción y compara su salida con la del código anterior (ejercicio 8). ¿Son iguales?

# %%
# No, no son iguales, ya que las categorias muestran el ordenamiento de los datos de forma distinta, por lo que la interpretacion de los mismos es distinta.
# Al invertir las categorias cambia por completo la interpretacion de la informacion.

# %%
air_df.unstack()
# Out:
#                 Site                      Value                          \
# Species           NO  NO2  NOX PM10 PM2.5    NO   NO2   NOX  PM10 PM2.5
# Month Day Time
# 01    01  00:00  CT3  CT3  CT3  CT3   CT3   3.5  30.8  36.2  35.7   NaN
#           01:00  CT3  CT3  CT3  CT3   CT3   3.6  31.5  37.0  28.5   NaN
#           02:00  CT3  CT3  CT3  CT3   CT3   2.2  27.3  30.7  22.7   NaN
#           03:00  CT3  CT3  CT3  CT3   CT3   2.1  23.5  26.8  20.5   NaN
#           04:00  CT3  CT3  CT3  CT3   CT3   3.3  28.0  33.0  22.1   NaN
# ...              ...  ...  ...  ...   ...   ...   ...   ...   ...   ...
# 12    31  19:00  CT3  CT3  CT3  CT3   CT3   0.7  17.5  18.5  16.3  -2.0
#           20:00  CT3  CT3  CT3  CT3   CT3   0.7  17.5  18.6  14.5   6.0
#           21:00  CT3  CT3  CT3  CT3   CT3   0.7  14.1  15.1   8.6   5.0
#           22:00  CT3  CT3  CT3  CT3   CT3   1.1  22.0  23.6  12.5   5.0
#           23:00  CT3  CT3  CT3  CT3   CT3   0.9  19.4  20.7  10.4   6.0
#
# ...

# %% [markdown]
# 10.	Explica cuáles son las diferencias y similitudes entre el par `melt()/pivot()` y el par `stack()/unstack()`. Si tuvieras que elegir una contraparte para `melt()` entre `stack()/unstack()`, ¿cuál elegirías? ¿Por qué?

# %%
# Explica las diferencias:

# Pivot nos permite realizar mas operaciones en el dataframe y manipular la informacion

# Similitudes: Ambas transforman la estructura de los datos

# %%
# La contraparte seria la funcion 'stack' porque el df es jerarquico y tiene un indice ordenado por lo que la
# funcion stack nos permite cambiar el orden del indice facilmente.

#Personalmente utilizo mucho la funcion stack y pivot en mi dia a dia, son utiles por la facilidad para manipular
# la estructura y el ordenamiento de los datos y generar dataframes nuevos.
