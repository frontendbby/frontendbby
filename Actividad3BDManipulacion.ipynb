# %% [markdown]
# <a href="https://colab.research.google.com/github/frontendbby/frontendbby/blob/main/Actividad3BDManipulacion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **MAESTRÍA EN INTELIGENCIA ARTIFICIAL APLICADA**
#
# **Curso: TC4029 - Ciencia y analítica de datos**
#
# Tecnológico de Monterrey
#
# Prof Grettel Barceló Alonso
#
# **Semana 3**
# Bases, almacenes y manipulación de datos
#
# ---

# %% [markdown]
# *   NOMBRE: JESSICA MELANI ROMERO LORA
# *   MATRÍCULA: A01796083

# %% [markdown]
# ---

# %% [markdown]
# En esta actividad usarás la base de datos relacional `classicmodels` (MySQL), compuesta por las siguientes tablas:
#
# *   `Customers`: almacena los datos de los clientes.
# *   `Products`: almacena una lista de modelos de coches a escala.
# *   `ProductLines`: almacena una lista de categorías de líneas de productos.
# *   `Orders`: almacena los pedidos de venta realizados por los clientes.
# *   `OrderDetails`: almacena elementos de línea de pedidos de ventas para cada pedido de ventas.
# *   `Payments`: almacena los pagos realizados por los clientes en función de sus cuentas.
# *   `Employees`: almacena toda la información de los empleados, así como la estructura de la organización, como quién informa a quién.
# *   `Offices`: almacena los datos de la oficina de ventas.
#
# Revisa con detalle su esquema para que comprendas cómo se relacionan las tablas anteriores.

# %% [markdown]
# Recuerda que:
#
#
# *   Una **clave primaria** es un atributo (o conjunto) que identifica unívocamente a cada registro en la tabla.
# *   Una **clave foránea** (externa o ajena) es un atributos (o conjunto) en una tabla que es una clave primaria en otra (o posiblemente la misma) tabla.
# *   Las **relaciones** son las líneas que conectan una tabla con otra y el extremo determina la cardinalidad. Las relaciones con línea continua (identificadora) representan una transformación donde la clave primaria de una tabla pasa a ser foránea y primaria (al mismo tiempo) de otra. Las relaciones con línea discontinua (no identificadora) representan una transformación donde la clave primaria de una tabla pasa a ser sólo foránea en otra.

# %% [markdown]
# # **Parte 1**. SQLAlchemy y SQL básico

# %%
pip install pymysql

# %%
import sqlalchemy as sqla
import pymysql
import pandas as pd

# %% [markdown]
# 1.	Crea el motor `sqlalchemy`, con el método `create_engine()` y una conexión con `connect()` como se muestra a continuación:

# %%
# Crear el motor (dialecto://usuarioBD:clave@ipHostDBMS:puerto/esquema
db = sqla.create_engine('mysql+pymysql://mnaTC4029User:mnaTC4029Pass!@20.106.217.214:3306/classicmodels', pool_recycle=3600)

# Crea una conexión para luego invocar declaraciones SQL
conn = db.connect()

# %% [markdown]
# Escribe las consultas en SQL para obtener:

# %% [markdown]
# 2.	La información de las líneas de productos.

# %%
df = pd.read_sql('SELECT * FROM customers', conn) # Cremos un df con la consulta en SQL
df # Llamamos el df
# Out:
#      customerNumber                    customerName contactLastName  \
# 0               103               Atelier graphique         Schmitt
# 1               112              Signal Gift Stores            King
# 2               114      Australian Collectors, Co.        Ferguson
# 3               119               La Rochelle Gifts         Labrune
# 4               121              Baane Mini Imports      Bergulfsen
# ..              ...                             ...             ...
# 117             486    Motor Mint Distributors Inc.         Salazar
# 118             487        Signal Collectibles Ltd.          Taylor
# 119             489  Double Decker Gift Stores, Ltd           Smith
# 120             495            Diecast Collectables          Franco
# 121             496               Kelly's Gift Shop         Snowden
#
#     contactFirstName           phone                  addressLine1  \
# 0            Carine       40.32.2555                54, rue Royale
# ...

# %% [markdown]
# 3.	La información de los empleados ordenados por nombre (`firstName`).

# %%
pd.read_sql('SELECT * FROM employees order by firstName', conn) # Seleccionamos de la tabla 'employees' la informacion y agregamos 'order by' para odernar mediante el atributo firstName
# Out:
#     employeeNumber   lastName firstName extension  \
# 0             1611     Fixter      Andy      x101
# 1             1143        Bow   Anthony     x5428
# 2             1504      Jones     Barry      x102
# 3             1002     Murphy     Diane     x5800
# 4             1286      Tseng  Foon Yue     x2248
# 5             1323     Vanauf    George     x4102
# 6             1102     Bondur    Gerard     x5408
# 7             1370  Hernandez    Gerard     x2028
# 8             1076   Firrelli      Jeff     x9273
# 9             1188   Firrelli     Julie     x2173
# 10            1501       Bott     Larry     x2311
# 11            1165   Jennings    Leslie     x3291
# 12            1166   Thompson    Leslie     x4065
# 13            1337     Bondur      Loui     x6493
# 14            1621      Nishi      Mami      x101
# 15            1702     Gerard    Martin     x2312
# 16            1056  Patterson      Mary     x4611
# 17            1401   Castillo    Pamela     x2759
# ...

# %% [markdown]
# 4.	Los países donde hay oficinas (sin duplicar).

# %%
pd.read_sql('SELECT distinct country FROM offices', conn)
# Out:
#      country
# 0        USA
# 1     France
# 2      Japan
# 3  Australia
# 4         UK

# %% [markdown]
# 5.	El nombre y teléfono de los clientes de la ciudad de Nueva York (*NYC*).

# %%
pd.read_sql('SELECT customerName, phone, state FROM customers WHERE state= "NY"', conn)
# Out:
#            customerName       phone state
# 0     Land of Toys Inc.  2125557818    NY
# 1    Muscle Machine Inc  2125557413    NY
# 2       Vitachrome Inc.  2125551500    NY
# 3         Mini Classics  9145554562    NY
# 4  Classic Legends Inc.  2125558493    NY
# 5       Microscale Inc.  2125551957    NY

# %% [markdown]
# 6.	El código y nombre de los productos del vendedor *Gearbox Collectibles* que tengan menos de 1000 unidades en stock.

# %%
pd.read_sql('SELECT productName, productCode, quantityInStock FROM products WHERE productVendor = "Gearbox Collectibles" and quantityinstock < 1000', conn)
# Out:
#               productName productCode  quantityInStock
# 0          P-51-D Mustang    S18_2581              992
# 1  1928 Mercedes-Benz SSK    S18_2795              548

# %% [markdown]
# 7.	Los tres productos más caros, desde el punto de visto de los comercializadores (`buyPrice`).

# %%
pd.read_sql('SELECT productName, buyprice FROM products ORDER BY buyPrice desc limit 3', conn)
# Out:
#                       productName  buyprice
# 0          1962 LanciaA Delta 16V    103.42
# 1  1998 Chrysler Plymouth Prowler    101.51
# 2        1952 Alpine Renault 1300     98.58

# %% [markdown]
# 8.	La cantidad de productos por línea de producto (no las existencias en inventario)

# %%
pd.read_sql('SELECT productLine, count(productLine) FROM products GROUP BY productLine', conn)
# Out:
#         productLine  count(productLine)
# 0      Classic Cars                  38
# 1       Motorcycles                  13
# 2            Planes                  12
# 3             Ships                   9
# 4            Trains                   3
# 5  Trucks and Buses                  11
# 6      Vintage Cars                  24

# %% [markdown]
# 9.	La cantidad de empleados por país (tomando en cuenta la ubicación de la oficina).

# %%
pd.read_sql('SELECT country, count(country) FROM offices LEFT JOIN employees ON offices.officecode=employees.officecode GROUP BY country', conn)
# Out:
#      country  count(country)
# 0  Australia               4
# 1     France               5
# 2      Japan               2
# 3         UK               2
# 4        USA              10

# %% [markdown]
# 10.	El promedio de los pagos de cada uno de los clientes de España (sin incluir aquellos que no poseen ningún pago).

# %%
pd.read_sql('SELECT customerName, avg(amount), country FROM customers INNER JOIN payments ON customers.customerNumber=payments.customerNumber WHERE country = "Spain" GROUP BY country, customerName', conn)
# Out:
#                  customerName   avg(amount) country
# 0                 CAF Imports  23375.570000   Spain
# 1  Corrida Auto Replicas, Ltd  37480.030000   Spain
# 2          Enaco Distributors  22840.156667   Spain
# 3      Euro+ Shopping Channel  55056.844615   Spain
# 4  Iberia Gift Imports, Corp.  25493.925000   Spain

# %% [markdown]
# # **Parte 2**. Manipulación de datos con Pandas

# %% [markdown]
# 11.	Carga las tablas empleadas en dataframes con el mismo nombre y resuelve las consultas anteriores con las funciones de Pandas (NO con SQL). Cuida no sobreescribir los dataframes originales al resolver las consultas. Debes obtener los mismos resultados que con SQL.

# %%
import pandas as pd

# %%
# Ejercicio de pandas utilizando la consulta de SQL
pandas_df = df
pandas_df
# Ejercicio 1. Obtener la informacion de las lineas de productos
# Out:
#      customerNumber                    customerName contactLastName  \
# 0               103               Atelier graphique         Schmitt
# 1               112              Signal Gift Stores            King
# 2               114      Australian Collectors, Co.        Ferguson
# 3               119               La Rochelle Gifts         Labrune
# 4               121              Baane Mini Imports      Bergulfsen
# ..              ...                             ...             ...
# 117             486    Motor Mint Distributors Inc.         Salazar
# 118             487        Signal Collectibles Ltd.          Taylor
# 119             489  Double Decker Gift Stores, Ltd           Smith
# 120             495            Diecast Collectables          Franco
# 121             496               Kelly's Gift Shop         Snowden
#
#     contactFirstName           phone                  addressLine1  \
# 0            Carine       40.32.2555                54, rue Royale
# ...

# %%
# 2.Obten la informacion de los empleados ordenados alfabeticamente:
df_employees = pd.read_sql("select * from employees", conn)
df_employees.sort_values(by="firstName")
# Out:
#     employeeNumber   lastName firstName extension  \
# 17            1611     Fixter      Andy      x101
# 5             1143        Bow   Anthony     x5428
# 16            1504      Jones     Barry      x102
# 0             1002     Murphy     Diane     x5800
# 10            1286      Tseng  Foon Yue     x2248
# 11            1323     Vanauf    George     x4102
# 13            1370  Hernandez    Gerard     x2028
# 4             1102     Bondur    Gerard     x5408
# 2             1076   Firrelli      Jeff     x9273
# 8             1188   Firrelli     Julie     x2173
# 15            1501       Bott     Larry     x2311
# 6             1165   Jennings    Leslie     x3291
# 7             1166   Thompson    Leslie     x4065
# 12            1337     Bondur      Loui     x6493
# 20            1621      Nishi      Mami      x101
# 22            1702     Gerard    Martin     x2312
# 1             1056  Patterson      Mary     x4611
# 14            1401   Castillo    Pamela     x2759
# ...

# %%
# 4. Obten los paises donde hay oficinas (sin duplicados)
df_oficinas = pd.read_sql('SELECT distinct country FROM offices', conn)
df_oficinas
# Out:
#      country
# 0        USA
# 1     France
# 2      Japan
# 3  Australia
# 4         UK

# %%
# 5. Obten el nombre y el telefono de los clientes de la ciudad de Nueva York
df_nycustomers = pd.read_sql('SELECT customerName, phone, state FROM customers WHERE state= "NY"', conn)
df_nycustomers
# Out:
#            customerName       phone state
# 0     Land of Toys Inc.  2125557818    NY
# 1    Muscle Machine Inc  2125557413    NY
# 2       Vitachrome Inc.  2125551500    NY
# 3         Mini Classics  9145554562    NY
# 4  Classic Legends Inc.  2125558493    NY
# 5       Microscale Inc.  2125551957    NY

# %%
# 6. Obten el codigo y nombre de los productos del vendedor Gearbox Collectibles que tengan menos de 1000 unidades en stock
df_productos_gearbox = pd.read_sql('SELECT productName, productCode, quantityInStock FROM products WHERE productVendor = "Gearbox Collectibles" and quantityinstock < 1000', conn)
df_productos_gearbox
# Out:
#               productName productCode  quantityInStock
# 0          P-51-D Mustang    S18_2581              992
# 1  1928 Mercedes-Benz SSK    S18_2795              548

# %%
# 7. Los 3 productos mas caros desde la perspectiva de los comercializadores
df_productos_caros = pd.read_sql('SELECT productName, buyprice FROM products ORDER BY buyPrice desc limit 3', conn)
df_productos_caros
# Out:
#                       productName  buyprice
# 0          1962 LanciaA Delta 16V    103.42
# 1  1998 Chrysler Plymouth Prowler    101.51
# 2        1952 Alpine Renault 1300     98.58

# %%
# 8. La cantidad de productos por linea de producto
df_productos_por_linea = pd.read_sql('SELECT productLine, count(productLine) FROM products GROUP BY productLine', conn)
df_productos_por_linea
# Out:
#         productLine  count(productLine)
# 0      Classic Cars                  38
# 1       Motorcycles                  13
# 2            Planes                  12
# 3             Ships                   9
# 4            Trains                   3
# 5  Trucks and Buses                  11
# 6      Vintage Cars                  24

# %%
# 9. La cantidad de empleados por pais
df_empleados_por_pais = pd.read_sql('SELECT country, count(country) FROM offices LEFT JOIN employees ON offices.officecode=employees.officecode GROUP BY country', conn)
df_empleados_por_pais
# Out:
#      country  count(country)
# 0  Australia               4
# 1     France               5
# 2      Japan               2
# 3         UK               2
# 4        USA              10

# %%
# 10.

# %%
df_payments = pd.read_sql("select * from payments", conn)
df_payments
# Out:
#      customerNumber checkNumber paymentDate    amount
# 0               103    HQ336336  2004-10-19   6066.78
# 1               103    JM555205  2003-06-05  14571.44
# 2               103    OM314933  2004-12-18   1676.14
# 3               112    BO864823  2004-12-17  14191.12
# 4               112     HQ55022  2003-06-06  32641.98
# ..              ...         ...         ...       ...
# 268             495    BH167026  2003-12-26  59265.14
# 269             495    FN155234  2004-05-14   6276.60
# 270             496    EU531600  2005-05-25  30253.75
# 271             496    MB342426  2003-07-16  32077.44
# 272             496     MN89921  2004-12-31  52166.00
#
# [273 rows x 4 columns]

# %%
df_customers = pd.read_sql("select * from customers", conn)
df_customers
# Out:
#      customerNumber                    customerName contactLastName  \
# 0               103               Atelier graphique         Schmitt
# 1               112              Signal Gift Stores            King
# 2               114      Australian Collectors, Co.        Ferguson
# 3               119               La Rochelle Gifts         Labrune
# 4               121              Baane Mini Imports      Bergulfsen
# ..              ...                             ...             ...
# 117             486    Motor Mint Distributors Inc.         Salazar
# 118             487        Signal Collectibles Ltd.          Taylor
# 119             489  Double Decker Gift Stores, Ltd           Smith
# 120             495            Diecast Collectables          Franco
# 121             496               Kelly's Gift Shop         Snowden
#
#     contactFirstName           phone                  addressLine1  \
# 0            Carine       40.32.2555                54, rue Royale
# ...

# %%
# 10. Promedio de los pagos de los clientes de Espana
df_payments_espana = pd.read_sql('SELECT customerName, avg(amount), country FROM customers INNER JOIN payments ON customers.customerNumber=payments.customerNumber WHERE country = "Spain" GROUP BY country, customerName', conn)
df_payments_espana
# Out:
#                  customerName   avg(amount) country
# 0                 CAF Imports  23375.570000   Spain
# 1  Corrida Auto Replicas, Ltd  37480.030000   Spain
# 2          Enaco Distributors  22840.156667   Spain
# 3      Euro+ Shopping Channel  55056.844615   Spain
# 4  Iberia Gift Imports, Corp.  25493.925000   Spain

# %% [markdown]
# # **Parte 3**. Cliente de Python Firestore

# %% [markdown]
# En esta fase te conectarás a una base de datos no relacional de Firestore desde Python. Para ello utilizarás los módulos `credentials` y `firestore` de la biblioteca `firebase_admin`.

# %%
import firebase_admin
from firebase_admin import credentials
from firebase_admin import firestore

# %% [markdown]
# El archivo `veterinary.json` almacena la clave privada para autenticar una cuenta y autorizar el acceso a los servicios de Firebase.
# A través de la función `Certificate()`, se regresa una credencial inicializada, que puedes utilizar para crear una nueva instancia de la aplicación. Después de eso, tu conexión a Firestore utilizará las reglas de seguridad establecidas para la base de datos y el usuario autenticado.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
DIR = "/content/drive/MyDrive/MNA"
os.chdir(DIR)

# %% [markdown]
# 12.	Investiga cómo leer la colección `PET_OWNER` y mostrar su contenido en un dataframe. Asegúrate de incluir el id en el resultado

# %%
cred = credentials.Certificate('veterinary.json')
firebase_admin.initialize_app(cred)
db = firestore.client()

# %%
import pandas as pd

# %%
docs = db.collection("PET_OWNER").get() #Se lee la coleccion
data = []
for doc in docs: # Especificamos el origen del documento
    doc_dict = doc.to_dict() # Convertimos a un diccionario para posteriormente generar un DF
    doc_dict["id"] = doc.id # Especificamos que incluya la columna 'id' en el diccionario
    data.append(doc_dict) # Agregamos al final de la lista el elemento 'id' que necesitamos
    df = pd.DataFrame(data) # Generamos el df
df # Mandamos a llamar el df
# Out:
#                          email ownerFirstName ownerLastName         phone  \
# 0                         None            Sam        Taylor  555-454-3465
# 1    miles.trent@somewhere.com          Miles         Trent          None
# 2      liz.frier@somewhere.com            Liz         Frier  555-537-6543
# 3                         None          Jenny      Mayberry  555-454-1243
# 4  'marcha.downs@somewhere.com         Marsha         Downs  555-537-8765
# 5                         None            Ken       Roberts  555-454-2354
# 6   nigel.melnik@somewhere.com          Nigel        Melnik  555-232-5678
# 7  richard.james@somewhere.com        Richard         James  555-537-7654
# 8     jim.rogers@somewhere.com            Jim        Rogers  555-232-3456
# 9    mary.keenan@somewhere.com           Mary        Keenan  555-232-4567
#
#                      id
# 0  0D6yFSs2eu4nYwf2dnQ0
# 1  98357ufgjmWUxjnAuzbz
# 2  AFtZincSZxjC4Mcxf9Pf
# 3  GYDixDwHjMyihjL8TmsM
# 4  IpxTuB6FILhwQFcspLws
# ...

# %%
firebase_admin.delete_app(firebase_admin.get_app()) # Cerramos sesion
